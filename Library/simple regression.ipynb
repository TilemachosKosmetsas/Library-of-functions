# %% [markdown]
# ---
# ### Question :
#
#  Write this as a linear system where the unknowns are $m$ and $b$.<br>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;The linear system would be as follows: <br><br>
# <center>
# $
# m
# \cdot
# \begin{bmatrix}
# x_{1}\\
# x_{2}\\
# \vdots\\
# x_{n}
# \end{bmatrix}
# +b
# =
# \begin{bmatrix}
# y_{1}\\
# y_{2}\\
# \vdots\\
# y_{n}
# \end{bmatrix}
# $
# </center><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# Where $m$ is the slope of the regression line and $b$ is the $y$ axis intercept.

# %% [markdown]
#  Write down, and solve the normal equations for the unknows $m$ and $b$.<br>
#    **Answer (3 marks):**

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;If $m = 0$ then $b$ should be $=y_{n}$, for the system to be solvable (the system has infininitely many solutions for every vector $x$).

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;If $m \neq 0$ then solving the system should go as follows:
# <center>
# $
# m
# \cdot
# \begin{bmatrix}
# x_{1}\\
# x_{2}\\
# \vdots\\
# x_{n}
# \end{bmatrix}
# +b
# =
# \begin{bmatrix}
# y_{1}\\
# y_{2}\\
# \vdots\\
# y_{n}
# \end{bmatrix}
# $<br>
# $\Leftrightarrow$
# </center>
#
# <br>
#
#
# $\text{Let A be: }
# \begin{bmatrix}
# 1 & x_{1}\\
# 1 & x_{2}\\
# \vdots & \vdots\\
# 1 & x_{n}
# \end{bmatrix}
# \text{ , w be:}
# \begin{bmatrix}
# b\\
# m
# \end{bmatrix}
# \text{ and y matrix/vector be:}
# \begin{bmatrix}
# y_{1}\\
# y_{2}\\
# \vdots\\
# y_{n}
# \end{bmatrix}
# $
#
# <br>
# Then the system above can be written as:
# <br>
# <center> $A \cdot w = y$
# </center>
#
#
#
# $\Leftrightarrow$
# <br>
# $
# \begin{bmatrix}
# 1 & x_{1}\\
# 1 & x_{2}\\
# \vdots & \vdots\\
# 1 & x_{n}
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# b\\
# m
# \end{bmatrix}
# =
# \begin{bmatrix}
# y_{1}\\
# y_{2}\\
# \vdots\\
# y_{n}
# \end{bmatrix}
# $<br>
# </center><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Where the first matrix's dimensions are $n \times 2$ , the second matrix's dimensions are
# $2 \times 1$  and the output vector/matrix $y$ dimensions are $n \times 1$
# <br><br>
#
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; We need to multiply with the transpose matrix of A (both hands of the equation-from the left side) in order to square the matrix. And assuming the $A^T\cdot A$ is invertible, we will then multiply both sides with $\left(A^T\cdot A\right)^{-1}$ in order to solve for $w$.
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
# That means solving for $m$ and $b$.
# Matrix $A^T$ dimensions are $2 \times n$. It then follows:
# <br><br>
#
# <center>
# $
# \begin{bmatrix}
# 1 & 1 & \cdots & 1\\
# x_{1} & x_{2} & \cdots & x_{n}
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# 1 & x_{1}\\
# 1 & x_{2}\\
# \vdots & \vdots\\
# 1 & x_{n}
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# b\\
# m
# \end{bmatrix}
# =
# \begin{bmatrix}
# 1 & 1 & \cdots & 1\\
# x_{1} & x_{2} & \cdots & x_{n}
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# y_{1}\\
# y_{2}\\
# \vdots\\
# y_{n}
# \end{bmatrix}
# $
# </center>
# <br>
#
# <center>
# $\Leftrightarrow$
# <br><br>
# $
# \begin{bmatrix}
# n &   \sum_{i=1}^{i=n} x_{i}  \\
# \sum_{i=1}^{i=n} x_{i} & \sum_{i=1}^{i=n} x_{i}^{2}
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# b\\
# m
# \end{bmatrix}
# =
# \begin{bmatrix}
# \sum_{i=1}^{i=n} y_{i}\\
# \sum_{i=1}^{i=n} x_{i} \cdot y_{i}
# \end{bmatrix}
# $
# </center>
# <br>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Where $A^T\cdot A$ is:
# \begin{bmatrix}
# n &   \sum_{i=1}^{i=n} x_{i}  \\
# \sum_{i=1}^{i=n} x_{i} & \sum_{i=1}^{i=n} x_{i}^{2}
# \end{bmatrix}
# <br>
# Then by multipling both sides (from the left) with $\left(A^T\cdot A \right)^{-1} $we can solve for $w$:
# <br>
# <center>
# $
# \begin{bmatrix}
# b\\
# m
# \end{bmatrix}
# =
# \left(\begin{bmatrix}
# n &   \sum_{i=1}^{i=n} x_{i}  \\
# \sum_{i=1}^{i=n} x_{i} & \sum_{i=1}^{i=n} x_{i}^{2}
# \end{bmatrix}\right)^{-1}
# \cdot
# \begin{bmatrix}
# \sum_{i=1}^{i=n} y_{i}\\
# \sum_{i=1}^{i=n} x_{i} \cdot y_{i}
# \end{bmatrix}
# $<br>
# $\Leftrightarrow$
# </center>
# <br>
#
#
# <center>
# $
# \begin{bmatrix}
# b\\
# m
# \end{bmatrix}
# =
# \frac{1}{n \cdot \sum_{i=1}^{i=n} x_{i}^{2} -\left( \sum_{i=1}^{i=n} x_{i}\right)^{2}}
# \cdot
# \begin{bmatrix}
# \sum_{i=1}^{i=n} x_{i}^{2} &   -\sum_{i=1}^{i=n} x_{i}  \\
# -\sum_{i=1}^{i=n} x_{i} & n
# \end{bmatrix}
# \cdot
# \begin{bmatrix}
# \sum_{i=1}^{i=n} y_{i}\\
# \sum_{i=1}^{i=n} x_{i} \cdot y_{i}
# \end{bmatrix}
# $
#  </center>
#
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Then $m$ and $b$ are equal to:
# <br>
# <center>
# $
# m= \frac{n \cdot \sum_{i=1}^{i=n}x_{i}y_{i} - \sum_{i=1}^{i=n}x_{i} \cdot \sum_{i=1}^{i=n}y_{i}}{n \cdot \sum_{i=1}^{i=n}x^{2}_{i} - \left(\sum_{i=1}^{i=n}x_{i} \right)^{2}} \\
# b = \frac{\sum_{i=1}^{i=n}x^{2}_{i} \cdot \sum_{i=1}^{i=n}y_{i} - \sum_{i=1}^{i=n}x_{i} \cdot \sum_{i=1}^{i=n}x_{i}y_{i}}{n \cdot \sum_{i=1}^{i=n}x^{2}_{i} - \left( \sum_{i=1}^{i=n}x_{i} \right)^{2}}
# $
#     </center>

# %% [markdown]
# Next we treat this as an optimisation problem. Instead of using the normal equations, we now look for $m$ and $b$ that minimises the mean squared error,
# $$
# E = \frac1N\sum_{n=1}^N (mx_n + b - y_n)^2.
# $$

# %% [markdown]
# ---
#
# ### Question:
#
#  Write down the equations $\frac{\partial E}{\partial m} = 0$ and $\frac{\partial E}{\partial b} =0$.<br>

# %% [markdown]
# <center>
#     $
#     \frac{\partial{E}}{\partial{m}} = 0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     \frac{2}{N}
#     \cdot
#     \sum_{i=1}^{i=N} \left( m \cdot x_{i} + b - y_{i} \right)
#     \cdot
#     x_{i}
#     =0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     \sum_{i=1}^{i=N} \left( m \cdot x_{i}^{2} + b \cdot x_{i} - y_{i}\cdot x_{i} \right)
#     =0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     m \cdot \sum_{i=1}^{i=N} x_{i}^{2} + b \cdot \sum_{i=1}^{i=N} x_{i} - \sum_{i=1}^{i=N}y_{i}\cdot x_{i}
#     =
#     0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     m \cdot \sum_{i=1}^{i=N} x_{i}^{2} + b \cdot \sum_{i=1}^{i=N} x_{i} = \sum_{i=1}^{i=N}y_{i}\cdot x_{i}
#     $
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; (EQ $1$)
#     <br><br>
#     and:
#     <br><br>
#     $
#     \frac{\partial{E}}{\partial{b}} = 0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     \frac{2}{N}
#     \cdot
#     \sum_{i=1}^{i=N} \left( m \cdot x_{i} + b - y_{i} \right)
#     =0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     m \cdot \sum_{i=1}^{i=N} x_{i} + b \cdot n - \sum_{i=1}^{i=N}y_{i}\cdot
#     =
#     0
#     $
#     <br>
#     $\Leftrightarrow$
#     <br>
#     $
#     m \cdot \sum_{i=1}^{i=N} x_{i} + b \cdot n  = \sum_{i=1}^{i=N}y_{i}
#     $
#     &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; (EQ $2$)
#     <br><br>
#     </center>

# %% [markdown]
# Write the equations as a linear system, and solve for $m$ and $b$. How does your answer compare with the answer you obtained above?<br>
#    <br>

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;For simplicity i will substitute:
# <center>
# $
# \sum_{i=1}^{i=N} x_{i}^{2}
# $ with SX2<br>
# $
# \sum_{i=1}^{i=N} x_{i}
# $
# with SX<br>
# $
# \sum_{i=1}^{i=N} x_{i} \cdot y_{i}
# $
# with SXY , and<br>
# $
# \sum_{i=1}^{i=N} y_{i}
# $
# with SY
# </center>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Assuming that the determinant of the coefficients of the linear system ( equations $1$ and $2$ ) is $\neq 0$ , then by using Krammer's rule we should get the following solutions for $m$ and $b$.
# <br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;$m$ should be:<br>
# <center>
#     $
#     m=\frac{D_{m}}{D}
#     $
#     </center>
#     <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;and $b$ should be:<br>
#     <center>
#     $
#     m=\frac{D_{b}}{D}
#     $
# </center>
# <br><br>
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;By sustituting we get:
# <center>
#     $
#     m=\frac{n \cdot SXY - SX \cdot SY}{n \cdot SX2 -SX^{2}}
#     $<br><br>
#     and
#     $
#     b=\frac{SX2 \cdot SY - SX \cdot SXY}{n \cdot SX2 -SX^{2}}
#     $
#     <br><br>
#     And by substituting back we get:<br> <br>
#     $
#     m= \frac{n \cdot \sum_{i=1}^{i=n}x_{i}y_{i} - \sum_{i=1}^{i=n}x_{i} \cdot \sum_{i=1}^{i=n}y_{i}}{n \cdot \sum_{i=1}^{i=n}x^{2}_{i} - \left(\sum_{i=1}^{i=n}x_{i} \right)^{2}} \\
# b = \frac{\sum_{i=1}^{i=n}x^{2}_{i} \cdot \sum_{i=1}^{i=n}y_{i} - \sum_{i=1}^{i=n}x_{i} \cdot \sum_{i=1}^{i=n}x_{i}y_{i}}{n \cdot \sum_{i=1}^{i=n}x^{2}_{i} - \left( \sum_{i=1}^{i=n}x_{i} \right)^{2}}
#     $<br>
#     </center>
# and these are exactly the same values/solutions for $m$ and $b$, like the ones we got previously by solving the normal equation.

# %% [markdown]
# ---

# %% [markdown]
# We now apply these ideas to a numerical problem. First we need to import a few models

# %%
# This ensures that any graphs we generate will be part of the notebook, instead of
# opening in a separate window
# %matplotlib inline

# %%
import numpy as np # import the numerical linear algebra module
from matplotlib import pyplot as plt
import pandas as pd

# %% [markdown]
# ## Generate and display data.
# In the code block below we generate data with a linear relationship and then plot.

# %%
x_train = np.linspace(0,1,100)
y_train = 0.2*x_train + 1 + 0.01*np.random.randn(x_train.shape[0])

plt.plot(x_train, y_train, 'r.')
plt.show()

# %% [markdown]
# ### Problem 1: Find $m$ and $b$ using numpy
#
# 1. Using numpy, create $A$ and $b$ for the system $Ax=b$ (here $x$ is the vector containing the unknown weight $w$ and offset $b$). <br> ** Answer (5 marks) **
#
# 2. Solve the normal equations for $m$ and $b$. <br> **Answer (5 marks)**

# %%
b = np.asarray(x_train)
col2 = np.ones(100)
A =  np.vstack((col2,b)).T

yvec=np.asarray(y_train)

A_normal =np.matmul(np.transpose(A),A)
b_normal =np.matmul(np.transpose(A),yvec)

# Solve
solver = np.linalg.solve(A_normal, b_normal)
b, m = solver[0] , solver[1]

# End of your code

# The computed values of m and b should be compared with the values
# m = 0.2 and b = 1.0, used to generate the data
print(m, b)
# Out:
# 0.199789781993011 0.998863109811571

# %% [markdown]
# ---

# %% [markdown]
# ### Question 4:
# 1. Why do the numerical values differ from the values used to generate the data?
# <br> **Answer (3 marks):**

# %% [markdown]
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;Because we are using a regression model to "reverse engineer" the initial equation that produced the points(x,y).
# We are doing so, by minimizing the squared errors sum. So the more data we feed to our regression model the more accurate.
# There can never be 0 error unless all points fall on the same line, and that is not how we created our points(x,y) initially.
# Our points had a "random" component in the end, and that is the error, we cannot simulate with our model.

# %% [markdown]
# ---
# ## Using normal equations is numerically unstable
#
# Although it does not matter much for the simple example above, in general it is bad practice to use the normal equations to solve the least squares problem. Surprisingly enough, the culprit is the *covariance* matrix $A^TA$. We cannot compute it in a numerically stable fashion. Technically, its condition number is roughly the square of the condition number of $A$ and in practice this means that we loose roughly half the precision if we calculate the covariance matrix.
#
# A full discussion is beyond the scope of the course, but the interested reader is encouraged to consult, Lloyd N. Trefethen and David Bau, III. NUMERICAL LINEAR ALGEBRA, SIAM 1997.
#
# A numerical stable way of solving the linear least squares problem is to first do a $QR$ factorization of $A$. If $A$ is an $m\times n$ dimensional array with $m>n$ (more equations than unknowns), then the $QR$ factorization is given by
# $$
# A = QR,
# $$
# where $Q$ is an $m\times n$ matrix with orthogonal columns, i.e. $Q^TQ=I$, and $R$ is an $n\times n$ upper triangular matrix. Assuming that $A$ has full rank, i.e. its columns are linearly independent, then it can be shown that $R$ is non-singular. One has to take some care, but there are a number of numerically stable algorithms to compute the $QR$ factorisation.
#
# Let's now substitute the $A=QR$ in the normal equations,
# $$
# (QR)^T QR x = (QR)^T b.
# $$
# Taking the orthogonality of $Q$ and the non-singularity of $R$ into account, this equation boils down to
# $$
# Rx = Q^Tb.
# $$
# Since $R$ is non-singular and upper traingular, this system is easily and efficiently solved.
#
# What has happened here? After we calculated the $QR$ algorithm in a stable manner, we did many of the calculations analytically (using $Q^TQ=I$ and cancelling $R^T$ from both sides), and that is done with infinite precision!

# %% [markdown]
# ---
# ### Problem 2:
# 1. Solve the linear least squares problem using the $QR$ factorization. With numpy. <br> ** Answer (5 marks):**

# %%
# Your code here
Q, R = np.linalg.qr(A)
# End of your code

print(Q.shape, '\n')
print('R = ', R, '\n')
print('Q^TQ = ', np.dot(Q.T,Q))
print(m, b)
# Out:
# (100, 2)
#
# R =  [[-10.          -5.        ]
#  [  0.           2.91576465]]
#
# Q^TQ =  [[ 1.00000000e+00 -2.08166817e-17]
#  [-2.08166817e-17  1.00000000e+00]]
# 0.199789781993011 0.998863109811571

# %%
# Your code here
Q_t_B=np.matmul(np.transpose(Q),yvec)
solver2=np.linalg.solve(R,Q_t_B)
b, m = solver2[0],solver2[1]
# End of your code

print(m,b)
# Out:
# 0.1997897819930102 0.9988631098115711

# %% [markdown]
# # Solve using scikit-learn
#
# First we need to import the necessary module from scikit-learn

# %%
# Import modules from sklearn
from sklearn.linear_model import  LinearRegression

# %% [markdown]
# ## Problem 3:
#
# 1. Solve the linear least squares problem using sklearn. <br>

# %%
# Fit the data to the model
model1 = LinearRegression()
X=np.array(x_train).reshape(-1,1)
Y=np.array(y_train).reshape(-1,1)
model1.fit(X,Y)
# Print the weight and offset. The values are the same as from the normal equations.
print(f'The slope of the line is {model1.coef_[0][0]} and the intercept is {model1.intercept_[0]}')
# Out:
# The slope of the line is 0.19978978199301 and the intercept is 0.9988631098115717

# %% [markdown]
# # Using Keras
#
# First import the necessary modules from keras

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam

# %% [markdown]
# ## Problem 4:
#
# 1. Solve the linear least squares problem using keras. <br> ** Answer (5 marks):**
# 2. Use the Adam optimiser and experiment with different learning rates. <br> ** Answer (5 marks):**
#
# **Note:** You should find everything you need on the internet
# * https://keras.io/getting-started/sequential-model-guide/
# * https://keras.io/optimizers/
# * https://keras.io/models/sequential/

# %%
model = Sequential()
model.add(Dense(1, input_dim=1, kernel_initializer='normal', activation='linear'))

# Compile model
model.compile(loss='mse', optimizer='adam', metrics=['mse'])

# Fit model: use a batch_size=20, epochs=300
model.fit(x=X, y=Y, batch_size=20, epochs=300, verbose=1)
# Out:
# Epoch 1/300
# 5/5 [==============================] - 0s 751us/step - loss: 1.1107 - mse: 1.1107
# Epoch 2/300
# 5/5 [==============================] - 0s 751us/step - loss: 1.0948 - mse: 1.0948
# Epoch 3/300
# 5/5 [==============================] - 0s 751us/step - loss: 1.0791 - mse: 1.0791
# Epoch 4/300
# 5/5 [==============================] - 0s 500us/step - loss: 1.0638 - mse: 1.0638
# Epoch 5/300
# 5/5 [==============================] - 0s 751us/step - loss: 1.0485 - mse: 1.0485
# Epoch 6/300
# 5/5 [==============================] - 0s 751us/step - loss: 1.0331 - mse: 1.0331
# Epoch 7/300
# 5/5 [==============================] - 0s 500us/step - loss: 1.0182 - mse: 1.0182
# Epoch 8/300
# 5/5 [==============================] - 0s 500us/step - loss: 1.0033 - mse: 1.0033
# Epoch 9/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.9883 - mse: 0.9883
# Epoch 10/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.9740 - mse: 0.9740
# Epoch 11/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.9595 - mse: 0.9595
# Epoch 12/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.9453 - mse: 0.9453
# Epoch 13/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.9312 - mse: 0.9312
# Epoch 14/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.9173 - mse: 0.9173
# Epoch 15/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.9034 - mse: 0.9034
# Epoch 16/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.8898 - mse: 0.8898
# Epoch 17/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.8765 - mse: 0.8765
# Epoch 18/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.8631 - mse: 0.8631
# Epoch 19/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.8501 - mse: 0.8501
# Epoch 20/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.8370 - mse: 0.8370
# Epoch 21/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.8244 - mse: 0.8244
# Epoch 22/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.8115 - mse: 0.8115
# Epoch 23/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.7991 - mse: 0.7991
# Epoch 24/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.7867 - mse: 0.7867
# Epoch 25/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.7745 - mse: 0.7745
# Epoch 26/300
# 5/5 [==============================] - 0s 750us/step - loss: 0.7624 - mse: 0.7624
# Epoch 27/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.7506 - mse: 0.7506
# Epoch 28/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.7388 - mse: 0.7388
# Epoch 29/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.7272 - mse: 0.7272
# Epoch 30/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.7158 - mse: 0.7158
# Epoch 31/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.7044 - mse: 0.7044
# Epoch 32/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.6933 - mse: 0.6933
# Epoch 33/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.6822 - mse: 0.6822
# Epoch 34/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.6713 - mse: 0.6713
# Epoch 35/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.6605 - mse: 0.6605
# Epoch 36/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.6498 - mse: 0.6498
# Epoch 37/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.6394 - mse: 0.6394
# Epoch 38/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.6291 - mse: 0.6291
# Epoch 39/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.6188 - mse: 0.6188
# Epoch 40/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.6088 - mse: 0.6088
# Epoch 41/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.5989 - mse: 0.5989
# Epoch 42/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.5890 - mse: 0.5890
# Epoch 43/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.5793 - mse: 0.5793
# Epoch 44/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.5697 - mse: 0.5697
# Epoch 45/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.5603 - mse: 0.5603
# Epoch 46/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.5510 - mse: 0.5510
# Epoch 47/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.5419 - mse: 0.5419
# Epoch 48/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.5328 - mse: 0.5328
# Epoch 49/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.5239 - mse: 0.5239
# Epoch 50/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.5151 - mse: 0.5151
# Epoch 51/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.5064 - mse: 0.5064
# Epoch 52/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.4978 - mse: 0.4978
# Epoch 53/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4894 - mse: 0.4894
# Epoch 54/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.4810 - mse: 0.4810
# Epoch 55/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4728 - mse: 0.4728
# Epoch 56/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4648 - mse: 0.4648
# Epoch 57/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.4568 - mse: 0.4568
# Epoch 58/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4489 - mse: 0.4489
# Epoch 59/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4412 - mse: 0.4412
# Epoch 60/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4335 - mse: 0.4335
# Epoch 61/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4260 - mse: 0.4260
# Epoch 62/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.4186 - mse: 0.4186
# Epoch 63/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4113 - mse: 0.4113
# Epoch 64/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.4041 - mse: 0.4041
# Epoch 65/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.3970 - mse: 0.3970
# Epoch 66/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.3900 - mse: 0.3900
# Epoch 67/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.3831 - mse: 0.3831
# Epoch 68/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.3763 - mse: 0.3763
# Epoch 69/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.3697 - mse: 0.3697
# Epoch 70/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.3631 - mse: 0.3631
# Epoch 71/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.3566 - mse: 0.3566
# Epoch 72/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.3502 - mse: 0.3502
# Epoch 73/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.3439 - mse: 0.3439
# Epoch 74/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.3378 - mse: 0.3378
# Epoch 75/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.3317 - mse: 0.3317
# Epoch 76/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.3257 - mse: 0.3257
# Epoch 77/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.3197 - mse: 0.3197
# Epoch 78/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.3139 - mse: 0.3139
# Epoch 79/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.3082 - mse: 0.3082
# Epoch 80/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.3026 - mse: 0.3026
# Epoch 81/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2971 - mse: 0.2971
# Epoch 82/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2916 - mse: 0.2916
# Epoch 83/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.2863 - mse: 0.2863
# Epoch 84/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2810 - mse: 0.2810
# Epoch 85/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2758 - mse: 0.2758
# Epoch 86/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2707 - mse: 0.2707
# Epoch 87/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.2657 - mse: 0.2657
# Epoch 88/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2607 - mse: 0.2607
# Epoch 89/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2559 - mse: 0.2559
# Epoch 90/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.2511 - mse: 0.2511
# Epoch 91/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.2464 - mse: 0.2464
# Epoch 92/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2418 - mse: 0.2418
# Epoch 93/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2373 - mse: 0.2373
# Epoch 94/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2328 - mse: 0.2328
# Epoch 95/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2285 - mse: 0.2285
# Epoch 96/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2241 - mse: 0.2241
# Epoch 97/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2199 - mse: 0.2199
# Epoch 98/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2158 - mse: 0.2158
# Epoch 99/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.2117 - mse: 0.2117
# Epoch 100/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.2077 - mse: 0.2077
# Epoch 101/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.2037 - mse: 0.2037
# Epoch 102/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1999 - mse: 0.1999
# Epoch 103/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1960 - mse: 0.1960
# Epoch 104/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1923 - mse: 0.1923
# Epoch 105/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1886 - mse: 0.1886
# Epoch 106/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1850 - mse: 0.1850
# Epoch 107/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1815 - mse: 0.1815
# Epoch 108/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1780 - mse: 0.1780
# Epoch 109/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1746 - mse: 0.1746
# Epoch 110/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1713 - mse: 0.1713
# Epoch 111/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1680 - mse: 0.1680
# Epoch 112/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1647 - mse: 0.1647
# Epoch 113/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1616 - mse: 0.1616
# Epoch 114/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1585 - mse: 0.1585
# Epoch 115/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1554 - mse: 0.1554
# Epoch 116/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1524 - mse: 0.1524
# Epoch 117/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1495 - mse: 0.1495
# Epoch 118/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1466 - mse: 0.1466
# Epoch 119/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1438 - mse: 0.1438
# Epoch 120/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1411 - mse: 0.1411
# Epoch 121/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1383 - mse: 0.1383
# Epoch 122/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1357 - mse: 0.1357
# Epoch 123/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1331 - mse: 0.1331
# Epoch 124/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1305 - mse: 0.1305
# Epoch 125/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1280 - mse: 0.1280
# Epoch 126/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1255 - mse: 0.1255
# Epoch 127/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1231 - mse: 0.1231
# Epoch 128/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1208 - mse: 0.1208
# Epoch 129/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1185 - mse: 0.1185
# Epoch 130/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1162 - mse: 0.1162
# Epoch 131/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1140 - mse: 0.1140
# Epoch 132/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1118 - mse: 0.1118
# Epoch 133/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1097 - mse: 0.1097
# Epoch 134/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1076 - mse: 0.1076
# Epoch 135/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.1055 - mse: 0.1055
# Epoch 136/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.1035 - mse: 0.1035
# Epoch 137/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.1016 - mse: 0.1016
# Epoch 138/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0997 - mse: 0.0997
# Epoch 139/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0978 - mse: 0.0978
# Epoch 140/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0959 - mse: 0.0959
# Epoch 141/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0941 - mse: 0.0941
# Epoch 142/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0924 - mse: 0.0924
# Epoch 143/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0907 - mse: 0.0907
# Epoch 144/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0890 - mse: 0.0890
# Epoch 145/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0873 - mse: 0.0873
# Epoch 146/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0857 - mse: 0.0857
# Epoch 147/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0841 - mse: 0.0841
# Epoch 148/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0826 - mse: 0.0826
# Epoch 149/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0811 - mse: 0.0811
# Epoch 150/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0796 - mse: 0.0796
# Epoch 151/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0782 - mse: 0.0782
# Epoch 152/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0767 - mse: 0.0767
# Epoch 153/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0753 - mse: 0.0753
# Epoch 154/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0740 - mse: 0.0740
# Epoch 155/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0727 - mse: 0.0727
# Epoch 156/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0714 - mse: 0.0714
# Epoch 157/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0701 - mse: 0.0701
# Epoch 158/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0689 - mse: 0.0689
# Epoch 159/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0677 - mse: 0.0677
# Epoch 160/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0665 - mse: 0.0665
# Epoch 161/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0654 - mse: 0.0654
# Epoch 162/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0642 - mse: 0.0642
# Epoch 163/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0631 - mse: 0.0631
# Epoch 164/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0621 - mse: 0.0621
# Epoch 165/300
# 5/5 [==============================] - 0s 750us/step - loss: 0.0610 - mse: 0.0610
# Epoch 166/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0600 - mse: 0.0600
# Epoch 167/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0590 - mse: 0.0590
# Epoch 168/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0580 - mse: 0.0580
# Epoch 169/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0571 - mse: 0.0571
# Epoch 170/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0561 - mse: 0.0561
# Epoch 171/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0552 - mse: 0.0552
# Epoch 172/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0543 - mse: 0.0543
# Epoch 173/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0535 - mse: 0.0535
# Epoch 174/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0526 - mse: 0.0526
# Epoch 175/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0518 - mse: 0.0518
# Epoch 176/300
# 5/5 [==============================] - 0s 750us/step - loss: 0.0510 - mse: 0.0510
# Epoch 177/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0502 - mse: 0.0502
# Epoch 178/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0495 - mse: 0.0495
# Epoch 179/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0487 - mse: 0.0487
# Epoch 180/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0480 - mse: 0.0480
# Epoch 181/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0473 - mse: 0.0473
# Epoch 182/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0466 - mse: 0.0466
# Epoch 183/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0459 - mse: 0.0459
# Epoch 184/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0452 - mse: 0.0452
# Epoch 185/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0446 - mse: 0.0446
# Epoch 186/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0439 - mse: 0.0439
# Epoch 187/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0433 - mse: 0.0433
# Epoch 188/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0427 - mse: 0.0427
# Epoch 189/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0421 - mse: 0.0421
# Epoch 190/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0416 - mse: 0.0416
# Epoch 191/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0410 - mse: 0.0410
# Epoch 192/300
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0405 - mse: 0.0405
# Epoch 193/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0400 - mse: 0.0400
# Epoch 194/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0394 - mse: 0.0394
# Epoch 195/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0390 - mse: 0.0390
# Epoch 196/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0385 - mse: 0.0385
# Epoch 197/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0380 - mse: 0.0380
# Epoch 198/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0375 - mse: 0.0375
# Epoch 199/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0371 - mse: 0.0371
# Epoch 200/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0366 - mse: 0.0366
# Epoch 201/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0362 - mse: 0.0362
# Epoch 202/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0358 - mse: 0.0358
# Epoch 203/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0354 - mse: 0.0354
# Epoch 204/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0350 - mse: 0.0350
# Epoch 205/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0346 - mse: 0.0346
# Epoch 206/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0342 - mse: 0.0342
# Epoch 207/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0338 - mse: 0.0338
# Epoch 208/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0335 - mse: 0.0335
# Epoch 209/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0331 - mse: 0.0331
# Epoch 210/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0328 - mse: 0.0328
# Epoch 211/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0324 - mse: 0.0324
# Epoch 212/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0321 - mse: 0.0321
# Epoch 213/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0318 - mse: 0.0318
# Epoch 214/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0315 - mse: 0.0315
# Epoch 215/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0312 - mse: 0.0312
# Epoch 216/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0309 - mse: 0.0309
# Epoch 217/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0306 - mse: 0.0306
# Epoch 218/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0303 - mse: 0.0303
# Epoch 219/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0301 - mse: 0.0301
# Epoch 220/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0298 - mse: 0.0298
# Epoch 221/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0295 - mse: 0.0295
# Epoch 222/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0293 - mse: 0.0293
# Epoch 223/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0290 - mse: 0.0290
# Epoch 224/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0288 - mse: 0.0288
# Epoch 225/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0286 - mse: 0.0286
# Epoch 226/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0283 - mse: 0.0283
# Epoch 227/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0281 - mse: 0.0281
# Epoch 228/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0279 - mse: 0.0279
# Epoch 229/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0277 - mse: 0.0277
# Epoch 230/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0275 - mse: 0.0275
# Epoch 231/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0273 - mse: 0.0273
# Epoch 232/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0271 - mse: 0.0271
# Epoch 233/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0269 - mse: 0.0269
# Epoch 234/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0267 - mse: 0.0267
# Epoch 235/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0265 - mse: 0.0265
# Epoch 236/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0263 - mse: 0.0263
# Epoch 237/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0261 - mse: 0.0261
# Epoch 238/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0260 - mse: 0.0260
# Epoch 239/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0258 - mse: 0.0258
# Epoch 240/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0256 - mse: 0.0256
# Epoch 241/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0255 - mse: 0.0255
# Epoch 242/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0253 - mse: 0.0253
# Epoch 243/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0251 - mse: 0.0251
# Epoch 244/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0250 - mse: 0.0250
# Epoch 245/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0248 - mse: 0.0248
# Epoch 246/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0247 - mse: 0.0247
# Epoch 247/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0246 - mse: 0.0246
# Epoch 248/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0244 - mse: 0.0244
# Epoch 249/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0243 - mse: 0.0243
# Epoch 250/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0241 - mse: 0.0241
# Epoch 251/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0240 - mse: 0.0240
# Epoch 252/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0239 - mse: 0.0239
# Epoch 253/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0237 - mse: 0.0237
# Epoch 254/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0236 - mse: 0.0236
# Epoch 255/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0235 - mse: 0.0235
# Epoch 256/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0234 - mse: 0.0234
# Epoch 257/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0233 - mse: 0.0233
# Epoch 258/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0231 - mse: 0.0231
# Epoch 259/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0230 - mse: 0.0230
# Epoch 260/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0229 - mse: 0.0229
# Epoch 261/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0228 - mse: 0.0228
# Epoch 262/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0227 - mse: 0.0227
# Epoch 263/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0226 - mse: 0.0226
# Epoch 264/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0225 - mse: 0.0225
# Epoch 265/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0224 - mse: 0.0224
# Epoch 266/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0223 - mse: 0.0223
# Epoch 267/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0222 - mse: 0.0222
# Epoch 268/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0221 - mse: 0.0221
# Epoch 269/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0220 - mse: 0.0220
# Epoch 270/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0219 - mse: 0.0219
# Epoch 271/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0218 - mse: 0.0218
# Epoch 272/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0217 - mse: 0.0217
# Epoch 273/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0216 - mse: 0.0216
# Epoch 274/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0215 - mse: 0.0215
# Epoch 275/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0214 - mse: 0.0214
# Epoch 276/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0213 - mse: 0.0213
# Epoch 277/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0213 - mse: 0.0213
# Epoch 278/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0212 - mse: 0.0212
# Epoch 279/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0211 - mse: 0.0211
# Epoch 280/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0210 - mse: 0.0210
# Epoch 281/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0209 - mse: 0.0209
# Epoch 282/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0208 - mse: 0.0208
# Epoch 283/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0208 - mse: 0.0208
# Epoch 284/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0207 - mse: 0.0207
# Epoch 285/300
# 5/5 [==============================] - 0s 501us/step - loss: 0.0206 - mse: 0.0206
# Epoch 286/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0205 - mse: 0.0205
# Epoch 287/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0204 - mse: 0.0204
# Epoch 288/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0204 - mse: 0.0204
# Epoch 289/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0203 - mse: 0.0203
# Epoch 290/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0202 - mse: 0.0202
# Epoch 291/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0201 - mse: 0.0201
# Epoch 292/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0200 - mse: 0.0200
# Epoch 293/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0200 - mse: 0.0200
# Epoch 294/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0199 - mse: 0.0199
# Epoch 295/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0198 - mse: 0.0198
# Epoch 296/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0198 - mse: 0.0198
# Epoch 297/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0197 - mse: 0.0197
# Epoch 298/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0196 - mse: 0.0196
# Epoch 299/300
# 5/5 [==============================] - 0s 751us/step - loss: 0.0195 - mse: 0.0195
# Epoch 300/300
# 5/5 [==============================] - 0s 500us/step - loss: 0.0195 - mse: 0.0195

# %%
# Print model weights, might not be exactly the same as above.
model.get_weights()
# Out:
# [array([[0.6530206]], dtype=float32), array([0.7290267], dtype=float32)]
